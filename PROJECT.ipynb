# %%
#1.UNDERSTAND THE DATA SET 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
data=pd.read_csv("PEP1.csv")
data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
#1.a
data.shape
# Out:
# (1460, 81)

# %%
#1.b
data.isna().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
data_num=data.select_dtypes(include=np.number)
data_cat=data.select_dtypes(include=np.object)

# %%
#1.c
for i in data_cat.columns:
    print(data[i].unique())
# Out:
# ['RL' 'RM' 'C (all)' 'FV' 'RH']
# ['Pave' 'Grvl']
# [nan 'Grvl' 'Pave']
# ['Reg' 'IR1' 'IR2' 'IR3']
# ['Lvl' 'Bnk' 'Low' 'HLS']
# ['AllPub' 'NoSeWa']
# ['Inside' 'FR2' 'Corner' 'CulDSac' 'FR3']
# ['Gtl' 'Mod' 'Sev']
# ['CollgCr' 'Veenker' 'Crawfor' 'NoRidge' 'Mitchel' 'Somerst' 'NWAmes'
#  'OldTown' 'BrkSide' 'Sawyer' 'NridgHt' 'mes' 'SawyerW' 'IDOTRR' 'MeadowV'
#  'Edwards' 'Timber' 'Gilbert' 'StoneBr' 'ClearCr' 'NPkVill' 'Blmngtn'
#  'BrDale' 'SWISU' 'Blueste']
# ['Norm' 'Feedr' 'PosN' 'Artery' 'RRAe' 'RRNn' 'RRAn' 'PosA' 'RRNe']
# ['Norm' 'Artery' 'RRNn' 'Feedr' 'PosN' 'PosA' 'RRAn' 'RRAe']
# ['1Fam' '2fmCon' 'Duplex' 'TwnhsE' 'Twnhs']
# ['2Story' '1Story' '1.5Fin' '1.5Unf' 'SFoyer' 'SLvl' '2.5Unf' '2.5Fin']
# ['Gable' 'Hip' 'Gambrel' 'Mansard' 'Flat' 'Shed']
# ['CompShg' 'WdShngl' 'Metal' 'WdShake' 'Membran' 'Tar&Grv' 'Roll'
#  'ClyTile']
# ['VinylSd' 'MetalSd' 'Wd Sdng' 'HdBoard' 'BrkFace' 'WdShing' 'CemntBd'
#  'Plywood' 'AsbShng' 'Stucco' 'BrkComm' 'AsphShn' 'Stone' 'ImStucc'
# ...

# %% [markdown]
# #2.	Generate a separate dataset for numerical and categorical variables

# %%
data_num=data.select_dtypes(include=np.number)
data_cat=data.select_dtypes(include=np.object)

# %% [markdown]
# 3.	EDA of numerical variables:
# a.	Missing value treatment
# b.	Identify the skewness and distribution
# c.	Identify significant variables using a correlation matrix
# d.	Pair plot for distribution and density

# %%
data_num
data_num.isna().sum()
# Out:
# Id                 0
# MSSubClass         0
# LotFrontage      259
# LotArea            0
# OverallQual        0
# OverallCond        0
# YearBuilt          0
# YearRemodAdd       0
# MasVnrArea         8
# BsmtFinSF1         0
# BsmtFinSF2         0
# BsmtUnfSF          0
# TotalBsmtSF        0
# 1stFlrSF           0
# 2ndFlrSF           0
# LowQualFinSF       0
# GrLivArea          0
# BsmtFullBath       0
# BsmtHalfBath       0
# FullBath           0
# HalfBath           0
# BedroomAbvGr       0
# KitchebvGr         0
# TotRmsAbvGrd       0
# Fireplaces         0
# GarageYrBlt       81
# GarageCars         0
# GarageArea         0
# WoodDeckSF         0
# OpenPorchSF        0
# EnclosedPorch      0
# 3SsnPorch          0
# ScreenPorch        0
# PoolArea           0
# MiscVal            0
# MoSold             0
# YrSold             0
# SalePrice          0
# dtype: int64

# %%
sns.boxplot(data["LotFrontage"])
# Out:
# <AxesSubplot:xlabel='LotFrontage'>

# %%
data_num["LotFrontage"].mean()
# Out:
# 70.04995836802665

# %%
data_num["LotFrontage"].median()
# Out:
# 69.0

# %%
data_num["LotFrontage"].mode()
# Out:
# 0    60.0
# dtype: float64

# %%
data_num["LotFrontage"].plot(kind="kde")
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
data_num["LotFrontage"]=data_num["LotFrontage"].fillna(65)
data_num["LotFrontage"].plot(kind="kde")
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
data["LotFrontage"].median()
# Out:
# 69.0

# %%
data["GarageYrBlt"].min()
# Out:
# 1900.0

# %%
data["GarageYrBlt"].max()
# Out:
# 2010.0

# %%
data["GarageYrBlt"].mode()
# Out:
# 0    2005.0
# dtype: float64

# %%
sns.boxplot(data["GarageYrBlt"])
# Out:
# <AxesSubplot:xlabel='GarageYrBlt'>

# %%
data["GarageYrBlt"].plot(kind="kde")
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
data.groupby("GarageCond")["GarageYrBlt"].median()
# Out:
# GarageCond
# Ex    1987.0
# Fa    1932.0
# Gd    1983.0
# Po    1920.0
# TA    1981.0
# Name: GarageYrBlt, dtype: float64

# %%
data_num["GarageYrBlt"]=data_num["GarageYrBlt"].fillna(1980)

# %%
data["GarageYrBlt"].plot(kind="kde")
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
data["MasVnrArea"].mean()
# Out:
# 103.68526170798899

# %%
sns.boxplot(data["MasVnrArea"])
# Out:
# <AxesSubplot:xlabel='MasVnrArea'>

# %%
data["MasVnrArea"]=data["MasVnrArea"].fillna(data["MasVnrArea"].mode())

# %%
data_num.isna().sum()
# Out:
# Id               0
# MSSubClass       0
# LotFrontage      0
# LotArea          0
# OverallQual      0
# OverallCond      0
# YearBuilt        0
# YearRemodAdd     0
# MasVnrArea       8
# BsmtFinSF1       0
# BsmtFinSF2       0
# BsmtUnfSF        0
# TotalBsmtSF      0
# 1stFlrSF         0
# 2ndFlrSF         0
# LowQualFinSF     0
# GrLivArea        0
# BsmtFullBath     0
# BsmtHalfBath     0
# FullBath         0
# HalfBath         0
# BedroomAbvGr     0
# KitchebvGr       0
# TotRmsAbvGrd     0
# Fireplaces       0
# GarageYrBlt      0
# GarageCars       0
# GarageArea       0
# WoodDeckSF       0
# OpenPorchSF      0
# EnclosedPorch    0
# 3SsnPorch        0
# ScreenPorch      0
# PoolArea         0
# MiscVal          0
# MoSold           0
# YrSold           0
# SalePrice        0
# dtype: int64

# %%
#3.b
data_num.skew()
# Out:
# Id                0.000000
# MSSubClass        1.407657
# LotFrontage       2.477423
# LotArea          12.207688
# OverallQual       0.216944
# OverallCond       0.693067
# YearBuilt        -0.613461
# YearRemodAdd     -0.503562
# MasVnrArea        2.669084
# BsmtFinSF1        1.685503
# BsmtFinSF2        4.255261
# BsmtUnfSF         0.920268
# TotalBsmtSF       1.524255
# 1stFlrSF          1.376757
# 2ndFlrSF          0.813030
# LowQualFinSF      9.011341
# GrLivArea         1.366560
# BsmtFullBath      0.596067
# BsmtHalfBath      4.103403
# FullBath          0.036562
# HalfBath          0.675897
# BedroomAbvGr      0.211790
# KitchebvGr        4.488397
# TotRmsAbvGrd      0.676341
# Fireplaces        0.649565
# GarageYrBlt      -0.678333
# GarageCars       -0.342549
# GarageArea        0.179981
# WoodDeckSF        1.541376
# OpenPorchSF       2.364342
# EnclosedPorch     3.089872
# 3SsnPorch        10.304342
# ScreenPorch       4.122214
# PoolArea         14.828374
# ...

# %%
#3b
for i in data_num.columns:
    data_num[i].plot(kind="kde")
    plt.show()

# %%
data_num.shape
# Out:
# (1460, 38)

# %%
data_num_imp=data_num[["OverallQual","YearBuilt","BsmtFinSF1",
              "TotalBsmtSF","1stFlrSF","GrLivArea","TotRmsAbvGrd","GarageYrBlt",
              "GarageCars","GarageArea","SalePrice"]]
data_num_imp.shape
# Out:
# (1460, 11)

# %%
#3.c
a=data_num.corr()
sns.heatmap(a)
a.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# ...

# %%
#3.d
sns.pairplot(data_num_imp)
plt.show()

# %%
#4.EDA of categorical variables

# %%
#4.a
data_cat.isna().sum()
# Out:
# MSZoning            0
# Street              0
# Alley            1369
# LotShape            0
# LandContour         0
# Utilities           0
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         0
# Exterior2nd         0
# MasVnrType          8
# ExterQual           0
# ExterCond           0
# Foundation          0
# BsmtQual           37
# BsmtCond           37
# BsmtExposure       38
# BsmtFinType1       37
# BsmtFinType2       38
# Heating             0
# HeatingQC           0
# CentralAir          0
# Electrical          1
# KitchenQual         0
# Functiol            0
# FireplaceQu       690
# GarageType         81
# GarageFinish       81
# GarageQual         81
# GarageCond         81
# PavedDrive          0
# PoolQC           1453
# Fence            1179
# MiscFeature      1406
# ...

# %%
data_cat.columns
# Out:
# Index(['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities',
#        'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
#        'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
#        'Functiol', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature',
#        'SaleType', 'SaleCondition'],
#       dtype='object')

# %%
data_miss=data_cat.loc[:,["BsmtQual","BsmtCond","BsmtExposure","BsmtFinType1","BsmtFinType2"]]
data_miss.columns
# Out:
# Index(['BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2'], dtype='object')

# %%
for i in data_miss.columns:
    data_cat[i]=data_cat[i].fillna(data_miss[i].mode()[0])

# %%
data_cat.isna().sum()
# Out:
# MSZoning            0
# Street              0
# Alley            1369
# LotShape            0
# LandContour         0
# Utilities           0
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         0
# Exterior2nd         0
# MasVnrType          8
# ExterQual           0
# ExterCond           0
# Foundation          0
# BsmtQual            0
# BsmtCond            0
# BsmtExposure        0
# BsmtFinType1        0
# BsmtFinType2        0
# Heating             0
# HeatingQC           0
# CentralAir          0
# Electrical          1
# KitchenQual         0
# Functiol            0
# FireplaceQu       690
# GarageType         81
# GarageFinish       81
# GarageQual         81
# GarageCond         81
# PavedDrive          0
# PoolQC           1453
# Fence            1179
# MiscFeature      1406
# ...

# %%
data_miss2=data_cat.loc[:,["GarageType","GarageFinish","GarageQual","GarageCond"]]
for i in data_miss2.columns:
    data_cat[i]=data_cat[i].fillna(data_miss2[i].mode()[0])

# %%
data_cat.isna().sum()
# Out:
# MSZoning            0
# Street              0
# Alley            1369
# LotShape            0
# LandContour         0
# Utilities           0
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         0
# Exterior2nd         0
# MasVnrType          8
# ExterQual           0
# ExterCond           0
# Foundation          0
# BsmtQual            0
# BsmtCond            0
# BsmtExposure        0
# BsmtFinType1        0
# BsmtFinType2        0
# Heating             0
# HeatingQC           0
# CentralAir          0
# Electrical          1
# KitchenQual         0
# Functiol            0
# FireplaceQu       690
# GarageType          0
# GarageFinish        0
# GarageQual          0
# GarageCond          0
# PavedDrive          0
# PoolQC           1453
# Fence            1179
# MiscFeature      1406
# ...

# %%
data_cat.shape
# Out:
# (1460, 43)

# %%
for i in data_cat.columns:
    sns.countplot(data_cat[i])
    plt.show()

# %%
data_cat_imp=data_cat[["MSZoning","LotConfig","Neighborhood","HouseStyle","Exterior1st","Exterior2nd",
                       "BsmtFinType1","GarageType"]]
data_cat_imp.shape
# Out:
# (1460, 8)

# %%
#5
new_data=pd.concat([data_cat_imp,data_num_imp],axis=1)
new_data.shape
# Out:
# (1460, 19)

# %%
new_data.columns
# Out:
# Index(['MSZoning', 'LotConfig', 'Neighborhood', 'HouseStyle', 'Exterior1st',
#        'Exterior2nd', 'BsmtFinType1', 'GarageType', 'OverallQual', 'YearBuilt',
#        'BsmtFinSF1', 'TotalBsmtSF', '1stFlrSF', 'GrLivArea', 'TotRmsAbvGrd',
#        'GarageYrBlt', 'GarageCars', 'GarageArea', 'SalePrice'],
#       dtype='object')

# %%
#6. 
data_num1=new_data.loc[:,"OverallQual":]
for i in data_num1.columns:
    sns.boxplot(data_num1[i])
    plt.show()
